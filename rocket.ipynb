# %%
import sys
# !{sys.executable} -m pip install opencv-python
# Out:
# ...
#   Using cached opencv_python-4.7.0.68-cp37-abi3-win_amd64.whl (38.2 MB)
# ...

# %%
import sys
# !{sys.executable} -m pip install vpython
# Out:
# ...
#      ---------------------------------------- 4.5/4.5 MB 5.0 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# ...
#   Using cached jupyter_server_proxy-3.2.2-py3-none-any.whl (36 kB)
# ...
#   Using cached autobahn-23.1.1.tar.gz (479 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached txaio-23.1.1-py2.py3-none-any.whl (30 kB)
# ...
#   Using cached cryptography-39.0.0-cp36-abi3-win_amd64.whl (2.5 MB)
# ...
#   Using cached hyperlink-21.0.0-py2.py3-none-any.whl (74 kB)
# ...
#   Using cached notebook-6.5.2-py3-none-any.whl (439 kB)
# ...

# %%
from cmath import sqrt
import cv2 as cv
from vpython import *
from time import sleep
from PIL import Image
print('This is a small rocket project created by HRK ')
print('Here you can design , calculate and also simulate the performance of Cryogenics rocket engine by providing some input ')

# img=cv.imread('C:\\Users\\HP\\Desktop\\rocket\\rocket.jpg')
# cv.imshow('engine',img)
cv.waitKey(0)
G=6.11*10**-11
M=5.97*10**24
R=6.37*10**6
Pa=98000

m1=float(input('enter the initial structural mass of your rocket here:'))
m2=float(input('enter the total mass of fuel+ oxidiser:'))
M1=m1+m2
F=(G*M*M1)/(R+1000)**2
print(F)

print(' Now please provide some information regarding your rocket engine')
print('now choose the fuel ')
print('1=CH4.'
 '2=Kerosene'
 '3=Hydrogen')
y=int(input('choose the fuel as 1 for CH4 , 2 for kerosene etc'))

if (y==1):
    q=13/12
    m=170
    m=16
elif (y==2):
    q=1.287
    m=170
elif (y==3):
    q=1.318
    m=2
else:
    print('wrong input, choose from 1 to 3')

print('value of gamma is '+ str(q))
print('value of molecular mass is '+ str(m))
Pc=float(input("enter the chamber pressure of your engine"))
Pe=float(input("enter the exit pressure of your engine"))
Rt=float(input('enter the throat radius of your rocket'))

At=3.14*Rt**2
x=(((2*q/(q+1))**(q/(q-1)))*((Pc/Pe)**(1/q))*((2/(q+1))**(-1/2)))/sqrt((2*q/(q-1))*(1-(Pe/Pc)**((q-1)/q))*((q+1)/(q-1)))
print('the area ratio is '+ str(x))
Ae=x*At
R0=8.314
R=R0/m
Tc=float(input('enter the chamber temperature'))
mdot = sqrt(q/(R*Tc))*Pc*At*(2/(q+1))**((q+1)/2*(q-1))# Rate of mass loss per time.
Vj=sqrt((2*q*R0*Tc)/((q-1)*m)*(1-(Pe/Pc)**(q-1)/q))

def printRocket():
     print("""
     /^\
     |-|
     | |
     |B|
     |E|
     |J|
     |O|
   //| |\\
  // | | \\
 | | | | | |
 -\\"\\"\\"-
 -//"//"//"-
     """)

printRocket()
sleep(3)
rocket_parts = []
height = 0.5
# rocket_parts.append(cylinder(pos=vector(0,0,0), axis=vector(0,height,0), radius=0.1, color=color.red))
rocket_parts.append(cylinder(pos=vector(0, 0, 0), color=color.white, size=vector(height, 0.1, 0.1), axis=vector(0, 1, 0), make_trail=True))
rocket_parts.append(cone(pos=rocket_parts[0].pos + rocket_parts[0].size.x * rocket_parts[0].axis * 2, color=color.orange, size=vector(rocket_parts[0].size.y, rocket_parts[0].size.y, rocket_parts[0].size.y), axis=vector(0, 1, 0)))
rocket_parts.append(triangle(v0=vertex(pos=rocket_parts[0].pos + 0.5 * rocket_parts[0].size.y * vector(1, 0, 0), color=color.green), v1=vertex(pos=rocket_parts[0].pos + 1.5 * rocket_parts[0].size.y * vector(1, 0, 0), color=color.green), v2=vertex(pos=rocket_parts[0].pos + 0.5 * rocket_parts[0].size.y * vector(1, 2, 0), color=color.green)))
rocket_parts.append(triangle(v0=vertex(pos=rocket_parts[0].pos + 0.5 * rocket_parts[0].size.y * vector(-1, 0, 0), color=color.green), v1=vertex(pos=rocket_parts[0].pos + 1.5 * rocket_parts[0].size.y * vector(-1, 0, 0), color=color.green), v2=vertex(pos=rocket_parts[0].pos + 0.5 * rocket_parts[0].size.y * vector(-1, 2, 0), color=color.green)))
rocket_parts.append(triangle(v0=vertex(pos=rocket_parts[0].pos + 0.5 * rocket_parts[0].size.y * vector(0, 0, 1), color=color.green), v1=vertex(pos=rocket_parts[0].pos + 1.5 * rocket_parts[0].size.y * vector(0, 0, 1), color=color.green), v2=vertex(pos=rocket_parts[0].pos + 0.5 * rocket_parts[0].size.y * vector(0, 2, 1), color=color.green)))
rocket_parts.append(triangle(v0=vertex(pos=rocket_parts[0].pos + 0.5 * rocket_parts[0].size.y * vector(0, 0, -1), color=color.green), v1=vertex(pos=rocket_parts[0].pos + 1.5 * rocket_parts[0].size.y * vector(0, 0, -1), color=color.green), v2=vertex(pos=rocket_parts[0].pos + 0.5 * rocket_parts[0].size.y * vector(0, 2, -1), color=color.green)))
# # ----------------------------------------
# rocket_parts.append(cylinder(pos=rocket_parts[0].pos + rocket_parts[0].size.x * rocket_parts[0].axis, color=color.white, size=vector(0.1, 0.1, 0.1), axis=vector(0, 1, 0)))
# rocket_parts.append(cone(pos=rocket_parts[0].pos + rocket_parts[0].size.x * rocket_parts[0].axis + rocket_parts[7].size.x * rocket_parts[7].axis, color=color.orange, size=vector(rocket_parts[7].size.y, rocket_parts[7].size.y, rocket_parts[7].size.y), axis=vector(0, 1, 0)))
# rocket_parts.append(triangle(v0=vertex(pos=rocket_parts[7].pos + 0.5 * rocket_parts[7].size.y * vector(1, 0, 0), color=color.green), v1=vertex(pos=rocket_parts[7].pos + 1.5 * rocket_parts[7].size.y * vector(1, 0, 0), color=color.green), v2=vertex(pos=rocket_parts[7].pos + 0.5 * rocket_parts[7].size.y * vector(1, 2, 0), color=color.green)))
# rocket_parts.append(triangle(v0=vertex(pos=rocket_parts[7].pos + 0.5 * rocket_parts[7].size.y * vector(-1, 0, 0), color=color.green), v1=vertex(pos=rocket_parts[7].pos + 1.5 * rocket_parts[7].size.y * vector(-1, 0, 0), color=color.green), v2=vertex(pos=rocket_parts[7].pos + 0.5 * rocket_parts[7].size.y * vector(-1, 2, 0), color=color.green)))
# rocket_parts.append(triangle(v0=vertex(pos=rocket_parts[7].pos + 0.5 * rocket_parts[7].size.y * vector(0, 0, 1), color=color.green), v1=vertex(pos=rocket_parts[7].pos + 1.5 * rocket_parts[7].size.y * vector(0, 0, 1), color=color.green), v2=vertex(pos=rocket_parts[7].pos + 0.5 * rocket_parts[7].size.y * vector(0, 2, 1), color=color.green)))
# rocket_parts.append(triangle(v0=vertex(pos=rocket_parts[7].pos + 0.5 * rocket_parts[7].size.y * vector(0, 0, -1), color=color.green), v1=vertex(pos=rocket_parts[7].pos + 1.5 * rocket_parts[7].size.y * vector(0, 0, -1), color=color.green), v2=vertex(pos=rocket_parts[7].pos + 0.5 * rocket_parts[7].size.y * vector(0, 2, -1), color=color.green)))

# rocket_parts.append(cylinder(pos=rocket_parts[7].pos + rocket_parts[7].size.x * rocket_parts[7].axis, color=color.white, size=vector(0.1, 0.1, 0.1), axis=vector(0, 1, 0)))
# rocket_parts.append(cone(pos=rocket_parts[7].pos + rocket_parts[7].size.x * rocket_parts[7].axis + rocket_parts[14].size.x * rocket_parts[14].axis, color=color.orange, size=vector(rocket_parts[14].size.y, rocket_parts[14].size.y, rocket_parts[14].size.y), axis=vector(0, 1, 0)))
# rocket_parts.append(triangle(v0=vertex(pos=rocket_parts[14].pos + 0.5 * rocket_parts[14].size.y * vector(1, 0, 0), color=color.green), v1=vertex(pos=rocket_parts[14].pos + 1.5 * rocket_parts[14].size.y * vector(1, 0, 0), color=color.green), v2=vertex(pos=rocket_parts[14].pos + 0.5 * rocket_parts[14].size.y * vector(1, 2, 0), color=color.green)))
# rocket_parts.append(triangle(v0=vertex(pos=rocket_parts[14].pos + 0.5 * rocket_parts[14].size.y * vector(-1, 0, 0), color=color.green), v1=vertex(pos=rocket_parts[14].pos + 1.5 * rocket_parts[14].size.y * vector(-1, 0, 0), color=color.green), v2=vertex(pos=rocket_parts[14].pos + 0.5 * rocket_parts[14].size.y * vector(-1, 2, 0), color=color.green)))
# rocket_parts.append(triangle(v0=vertex(pos=rocket_parts[14].pos + 0.5 * rocket_parts[14].size.y * vector(0, 0, 1), color=color.green), v1=vertex(pos=rocket_parts[14].pos + 1.5 * rocket_parts[14].size.y * vector(0, 0, 1), color=color.green), v2=vertex(pos=rocket_parts[14].pos + 0.5 * rocket_parts[14].size.y * vector(0, 2, 1), color=color.green)))
# rocket_parts.append(triangle(v0=vertex(pos=rocket_parts[14].pos + 0.5 * rocket_parts[14].size.y * vector(0, 0, -1), color=color.green), v1=vertex(pos=rocket_parts[14].pos + 1.5 * rocket_parts[14].size.y * vector(0, 0, -1), color=color.green), v2=vertex(pos=rocket_parts[14].pos + 0.5 * rocket_parts[14].size.y * vector(0, 2, -1), color=color.green)))

# rocket_parts.append(cylinder(pos=rocket_parts[14].pos + rocket_parts[14].size.x * rocket_parts[14].axis, color=color.white, size=vector(0.1, 0.1, 0.1), axis=vector(0, 1, 0)))
# rocket_parts.append(cone(pos=rocket_parts[14].pos + rocket_parts[14].size.x * rocket_parts[14].axis + rocket_parts[21].size.x * rocket_parts[21].axis, color=color.orange, size=vector(rocket_parts[21].size.y, rocket_parts[21].size.y, rocket_parts[21].size.y), axis=vector(0, 1, 0)))
# rocket_parts.append(triangle(v0=vertex(pos=rocket_parts[21].pos + 0.5 * rocket_parts[21].size.y * vector(1, 0, 0), color=color.green), v1=vertex(pos=rocket_parts[21].pos + 1.5 * rocket_parts[21].size.y * vector(1, 0, 0), color=color.green), v2=vertex(pos=rocket_parts[21].pos + 0.5 * rocket_parts[21].size.y * vector(1, 2, 0), color=color.green)))
# rocket_parts.append(triangle(v0=vertex(pos=rocket_parts[21].pos + 0.5 * rocket_parts[21].size.y * vector(-1, 0, 0), color=color.green), v1=vertex(pos=rocket_parts[21].pos + 1.5 * rocket_parts[21].size.y * vector(-1, 0, 0), color=color.green), v2=vertex(pos=rocket_parts[21].pos + 0.5 * rocket_parts[21].size.y * vector(-1, 2, 0), color=color.green)))
# rocket_parts.append(triangle(v0=vertex(pos=rocket_parts[21].pos + 0.5 * rocket_parts[21].size.y * vector(0, 0, 1), color=color.green), v1=vertex(pos=rocket_parts[21].pos + 1.5 * rocket_parts[21].size.y * vector(0, 0, 1), color=color.green), v2=vertex(pos=rocket_parts[21].pos + 0.5 * rocket_parts[21].size.y * vector(0, 2, 1), color=color.green)))
# rocket_parts.append(triangle(v0=vertex(pos=rocket_parts[21].pos + 0.5 * rocket_parts[21].size.y * vector(0, 0, -1), color=color.green), v1=vertex(pos=rocket_parts[21].pos + 1.5 * rocket_parts[21].size.y * vector(0, 0, -1), color=color.green), v2=vertex(pos=rocket_parts[21].pos + 0.5 * rocket_parts[21].size.y * vector(0, 2, -1), color=color.green)))

# rocket_parts.append(cylinder(pos=rocket_parts[21].pos + rocket_parts[21].size.x * rocket_parts[21].axis, color=color.white, size=vector(0.1, 0.1, 0.1), axis=vector(0, 1, 0)))
# rocket_parts.append(cone(pos=rocket_parts[21].pos + rocket_parts[21].size.x * rocket_parts[21].axis + rocket_parts[28].size.x * rocket_parts[28].axis, color=color.orange, size=vector(rocket_parts[28].size.y, rocket_parts[28].size.y, rocket_parts[28].size.y), axis=vector(0, 1, 0)))
# rocket_parts.append(triangle(v0=vertex(pos=rocket_parts[28].pos + 0.5 * rocket_parts[28].size.y * vector(1, 0, 0), color=color.green), v1=vertex(pos=rocket_parts[28].pos + 1.5 * rocket_parts[28].size.y * vector(1, 0, 0), color=color.green), v2=vertex(pos=rocket_parts[28].pos + 0.5 * rocket_parts[28].size.y * vector(1, 2, 0), color=color.green)))
# rocket_parts.append(triangle(v0=vertex(pos=rocket_parts[28].pos + 0.5 * rocket_parts[28].size.y * vector(-1, 0, 0), color=color.green), v1=vertex(pos=rocket_parts[28].pos + 1.5 * rocket_parts[28].size.y * vector(-1, 0, 0), color=color.green), v2=vertex(pos=rocket_parts[28].pos + 0.5 * rocket_parts[28].size.y * vector(-1, 2, 0), color=color.green)))
# rocket_parts.append(triangle(v0=vertex(pos=rocket_parts[28].pos + 0.5 * rocket_parts[28].size.y * vector(0, 0, 1), color=color.green), v1=vertex(pos=rocket_parts[28].pos + 1.5 * rocket_parts[28].size.y * vector(0, 0, 1), color=color.green), v2=vertex(pos=rocket_parts[28].pos + 0.5 * rocket_parts[28].size.y * vector(0, 2, 1), color=color.green)))
# rocket_parts.append(triangle(v0=vertex(pos=rocket_parts[28].pos + 0.5 * rocket_parts[28].size.y * vector(0, 0, -1), color=color.green), v1=vertex(pos=rocket_parts[28].pos + 1.5 * rocket_parts[28].size.y * vector(0, 0, -1), color=color.green), v2=vertex(pos=rocket_parts[28].pos + 0.5 * rocket_parts[28].size.y * vector(0, 2, -1), color=color.green)))




# M1 = 1000
# m2 = 1000

rocket = compound(rocket_parts, pos=vector(0, 0, 0))
rocket.velocity = vector(0, 0, 0)
rocket.mass = M1
rocket.fuel_mass = m2
attach_trail(rocket)
rocket.pos=vector(0,0,0)
initial_mass = rocket.mass + rocket.fuel_mass
initial_fuel_mass = rocket.fuel_mass
# rocket.velo=0
graph(fast=True)


r_pos = gcurve(color=color.red)
height1=0.5
earth=sphere( pos=vector(0, -height1* 1000, 0), color=color.green, radius=499)
ground = box(pos=vector(0, 0.01, 0), color=color.yellow, size=vector(20, 2, 20))
exhaust_velocity = vector(0,Vj,0)
dt = 0.01
t = 0
scene.camera.follow(rocket)
rocket.vel=mdot*dt
height2=1000
rocket.velo=0
r_vec=vector(0,-6370000,0)
r_vec2=vector(0, height2, 0)


while True:
    rate(50)
    if(rocket.fuel_mass > 0 or rocket.vel> 0):
        center_pos = vector(0, -6370000, 0)
        dm = mdot*dt # Amount of mass lost in time dt.
        F1 = (G*M*M1)/(r_vec.y**2)
        # F2 = (G*M*m2)/(r_vec2.y**2)
        # F = F1 + F2
        # rocket.velocity = rocket.velocity + (F/rocket.mass)*dt
        # rocket.pos = rocket.pos + rocket.velocity*dt
        # r_vec = center_pos - rocket.pos
        # r_vec2 = rocket.pos - center_pos
    if(mdot>0):
        rocket.vel = rocket.vel + (mdot*(Vj)+(Pe-Pa)*Ae-F1)*dt/(rocket.mass+rocket.fuel_mass)
        # F2 = (G*M*m2)/(r_vec2.y**2)
        # F = F1 + F2
        # rocket.velocity = rocket.velocity + (F/rocket.mass)*dt
        # rocket.pos = rocket.pos + rocket.velocity*dt
        # r_vec = center_pos - rocket.pos
        # r_vec2 = rocket.pos - center_pos
        # rocket.velocity=vector(0,rocket.vel,0)
        # rocket.pos = rocket.pos + rocket.velocity*dt
        # r_vec = center_pos - rocket.pos
        # t = t + dt
        # r_pos.plot(pos=(t,rocket.pos.y))
        # print('time=',t, 'rocket.pos.y=', rocket.pos.y ,'rocket fuel mass=',rocket.fuel_mass, 'dm=',dm ,'rocket velocity=', rocket.vel, 'gravity=',F1, r_vec.y,height2,'exhaust velo=',Vj)
        

    else:
        # rocket.vel = rocket.vel + (Pe-Pa)*Ae*dt/(rocket.mass+rocket.fuel_mass)
        rocket.vel = rocket.vel - (F1/rocket.mass)*dt
        print('fuel finished!')
        # rocket.velocity=vector(0,rocket.vel,0)
        # rocket.pos = rocket.pos + rocket.velocity*dt
        # r_vec = center_pos - rocket.pos
        # t = t + dt
        # r_pos.plot(pos=(t,rocket.pos.y))
        # print('time=',t, 'rocket.pos.y=', rocket.pos.y ,'rocket fuel mass=',rocket.fuel_mass, 'dm=',dm ,'rocket velocity=', rocket.vel, 'gravity=',F1, r_vec.y,height2,'exhaust velo=',Vj)
    # if(rocket.vel>0):
    #     rocket.vel = rocket.vel + (Pe-Pa)*Ae*dt/(rocket.mass+rocket.fuel_mass)
        
        rocket.velocity=vector(0,rocket.vel,0)
        rocket.pos = rocket.pos + rocket.velocity*dt
        r_vec = center_pos - rocket.pos
    if(rocket.fuel_mass>dm):
        rocket.fuel_mass = rocket.fuel_mass - dm
    else:
        rocket.fuel_mass = 0
        t = t + dt
        r_pos.plot(pos=(t,rocket.pos.y))
        print('time=',t, 'rocket.pos.y=', rocket.pos.y ,'rocket fuel mass=',rocket.fuel_mass, 'dm=',dm ,'rocket velocity=', rocket.vel, 'gravity=',F1, r_vec.y,height2,'exhaust velo=',Vj) 
        M1=M1-dm
    if(rocket.fuel_mass <= 0):
        rocket.fuel_mass=0
        dm=0
        mdot=0

    #     rocket.vel = rocket.vel - (F1/rocket.mass)*dt
    #     rocket.velocity=vector(0,rocket.vel,0)
    #     rocket.pos = rocket.pos + rocket.velocity*dt
    #     r_vec = center_pos - rocket.pos
    #     t = t + dt
    #     r_pos.plot(pos=(t,rocket.pos.y))
    #     print('time=',t, 'rocket.pos.y=', rocket.pos.y ,'rocket fuel mass=',rocket.fuel_mass, 'dm=',dm ,'rocket velocity=', rocket.vel, 'gravity=',F1, r_vec.y,height2,'exhaust velo=',Vj)
    # if(rocket.pos.y>0):
    #     rocket.vel = rocket.vel - (F1/rocket.mass)*dt
    #     rocket.velocity=vector(0,rocket.vel,0)
    #     rocket.pos = rocket.pos + rocket.velocity*dt
    #     r_vec = center_pos - rocket.pos
    #     t = t + dt
    #     r_pos.plot(pos=(t,rocket.pos.y))
    #     print('time=',t, 'rocket.pos.y=', rocket.pos.y ,'rocket fuel mass=',rocket.fuel_mass, 'dm=',dm ,'rocket velocity=', rocket.vel, 'gravity=',F1, r_vec.y,height2,'exhaust velo=',Vj)
        

    else:
        pass
    height2=abs(G*M/((G*M/r_vec.y)-0.5*(rocket.vel**2)))
    
else:
    print('descending !')
    center_pos2 = vector(0, -6370000, 0)
    F2 = (G * M * m1) / (r_vec.y ** 2)
    rocket.velo = sqrt((2*G*M)/abs(r_vec.y))
    rocket.velocity2 = vector(0, rocket.velo, 0)
    rocket.pos = rocket.pos - rocket.velocity2 * dt
    r_vec = center_pos2 - rocket.pos
    t = t + dt
    r_pos.plot(pos=(t, rocket.pos.y))
    print(t, rocket.pos, F2, rocket.velo, r_vec.y)
    sleep(0.01)
# else:
    #     rocket.vel = rocket.vel - F1*dt/(rocket.mass+rocket.fuel_mass)




#     if(rocket.fuel_mass > 0):
#         rocket.fuel_mass = rocket.fuel_mass - dm
#         rocket.mass = rocket.mass + dm
#     rocket.pos = rocket.pos + rocket.vel*dt
#     r_vec = r_vec + rocket.vel*dt
#     r_vec2 = r_vec2 + rocket.vel*dt
#     r_pos.plot(pos=(t, r_vec.y))
#     t = t + dt
#     if(r_vec.y < 0):
#         break

# print("Rocket has landed")
# print("Rocket mass: ", rocket.mass)
# print("Rocket fuel mass: ", rocket.fuel_mass)
# print("Rocket initial mass: ", initial_mass)
# print("Rocket initial fuel mass: ", initial_fuel_mass)
# print("Rocket final mass: ", rocket.mass + rocket.fuel_mass)
# print("Rocket final fuel mass: ", rocket.fuel_mass)
# print("Rocket mass lost: ", initial_mass - rocket.mass - rocket.fuel_mass)
# print("Rocket fuel mass lost: ", initial_fuel_mass - rocket.fuel_mass)
# print("Rocket final velocity: ", rocket.vel)
# print("Rocket final height: ", r_vec.y)
# print("Rocket final time: ", t)
# Out:
# This is a small rocket project created by HRK
# Here you can design , calculate and also simulate the performance of Cryogenics rocket engine by providing some input
# 269.6010541211734
#  Now please provide some information regarding your rocket engine
# now choose the fuel
# 1=CH4.2=Kerosene3=Hydrogen
# value of gamma is 1.318
# value of molecular mass is 2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 50
#      47 Rt=float(input('enter the throat radius of your rocket'))
#      49 At=3.14*Rt**2
# ---> 50 x=(((2*q/(q+1))**(q/(q-1)))*((Pc/Pe)**(1/q))*((2/(q+1))**(-1/2)))/sqrt((2*q/(q-1))*(1-(Pe/Pc)**((q-1)/q))*((q+1)/(q-1)))
#      51 print('the area ratio is '+ str(x))
#      52 Ae=x*At
#
# ValueError: math domain error
